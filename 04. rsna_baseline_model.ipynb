# %% [markdown]
# # 04. RSNA Knee — Baseline Model
#
# Baseline TRƯỚC khi thử phương pháp phức tạp (theo nguyên tắc baseline-first). Ghi nhận đầy đủ Experiment ID, seed, hyperparameter theo checklist reproducibility.

# %%
import sys, os
sys.path.append('..')
from rsna_lib import RANDOM_SEED

EXPERIMENT_ID = 'EXP-001'
SEED = RANDOM_SEED
print(EXPERIMENT_ID, SEED)

# %% [markdown]
# ## TODO
# - Load train/val index (đã split patient/study-level ở bước 03)
# - Baseline đơn giản trước (vd: logistic regression trên feature thống kê, hoặc CNN 2.5D nhẹ) — KHÔNG nhảy thẳng vào kiến trúc phức tạp.
# - Đánh giá bằng macro ROC-AUC (đúng metric chính thức của competition).
# - Ghi log: dataset version, code commit, hyperparameter, kết quả.
